# %% [markdown]
# # Follow this article
#
# https://medium.com/@ashwindesilva/how-to-use-google-colaboratory-to-clone-a-github-repository-e07cf8d3d22b
#
# https://navan0.medium.com/how-to-push-files-into-github-from-google-colab-379fd0077aa8

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
#  Finance   HowToColabANDGithub.ipynb  'OpenAI Gym Learning 2.ipynb'
#  FinBERT   Kaggle		      'OpenAI Gym Learning.ipynb'

# %%
# %cd gdrive/My Drive/Github
# Out:
# /content/gdrive/My Drive/Github

# %%
# !git config — global user.email 'omigu094@uottawa.ca'
# !git config — global user.name 'Olivier222'

# %%
# !git clone https://github.com/Olivier222/Market-predictor.git
# Out:
# Cloning into 'Market-predictor'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 129 (delta 39), reused 79 (delta 22), pack-reused 0
# Receiving objects: 100% (129/129), 312.83 KiB | 4.06 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# %cd /content/gdrive/MyDrive/Github/Market-predictor
# !ls
# Out:
# /content/gdrive/MyDrive/Github/Market-predictor
#  libraries		 'OpenAI Trading Enironment.ipynb'
#  main.py		  README.md
#  Market_Predictor.ipynb   sources
#  models			 'Yahoo Dataset Builder.ipynb'
#  MoM

# %%
# !git pull
# Out:
# Already up to date.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cd gdrive/My Drive/Github/Market-predictor

# !git pull

# %% [markdown]
# # Initialize "local" git repo on google drive
#
# Only need to run this once per repo at the begining when you start developing using this workflow

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# cd into the folder where you want the git repo to be located
# %cd gdrive/MyDrive/path-to-parent-folder-on-gdrive

# !git config --global user.email 'You@Your.com'
# !git config --global user.name 'Username'

#clone repo from github
# !git clone https://github.com/<username>/<reponame>.git

# %%
# %cd /content/gdrive/MyDrive/path-to-repo
# !git pull
# !ls

# %% [markdown]
# # Git commands for colab workflow

# %% [markdown]
# Connect google drive, enter repo and pull most recent repo

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %cd /content/gdrive/MyDrive/path-to-repo

# !git config --global user.email 'You@Your.com'
# !git config --global user.name 'Username'

# !git pull

# %% [markdown]
# Add all the files like

# %%
# !git add -A

# %% [markdown]
# then commit

# %%
# !git commit -m 'my first commit with colab'

# %% [markdown]
# this is the most important line, when you add the git remote origin you need to pass your Github credentials with the URL like,

# %%
# !git remote add origin https://<username>:<password>@github.com/<username>/reponame.git

# %% [markdown]
# if you got “fatal: remote origin already exists” error try running this command

# %%
# !git remote rm origin

# %% [markdown]
# at last, push your awesomeness

# %%
# !git push -u origin <branch>
